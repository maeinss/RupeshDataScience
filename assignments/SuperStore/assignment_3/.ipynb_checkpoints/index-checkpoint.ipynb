# %% [markdown]
# # [Table Of Contents](#)
# ### The Art of Data Storytelling

# %% [markdown]
# # The Global Superstore Case
#
# This page contains student files for the case "Modern Retail Analytics: Data Visualization Using Tableau." It includes three detailed tutorials that can be used by instructors in the classroom to introduce students to Tableau and Data Storytelling in the context of retail strategy and operations (using the [Global Superstore dataset](files/Global.Superstore.xlsx) that is made available with Tableau).

# %% [markdown]
# ### Assignment Three

# %% [markdown]
# 1. Assess Nigeria’s profitability (i.e., total profit) for 2014. How does it compare to other African countries?
# 2. What factors might be responsible for Nigeria’s poor performance? You might want to investigate shipping costs and the average discount as potential root causes.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# dataStore = pd.read_csv('Global.Superstore.xlsx', error_bad_lines=False)
# df = pd.read_csv("Global.Superstore.xlsx")
fileName="Global.Superstore.xlsx"
df = pd.read_excel(fileName)

# %%
df.head()
# Out:
#    Row ID         Order ID Order Date            Ship Date     Ship Mode  \
# 0   32298   CA-2012-124891 2014-07-31  2014-07-31 00:00:00      Same Day
# 1   26341    IN-2013-77878 2015-02-05  2015-02-07 00:00:00  Second Class
# 2   25330    IN-2013-71249 2015-10-17  2015-10-18 00:00:00   First Class
# 3   13524  ES-2013-1579342 2015-01-28  2015-01-30 00:00:00   First Class
# 4   47221     SG-2013-4320 2015-11-05  2015-11-06 00:00:00      Same Day
#
#   Customer ID     Customer Name      Segment           City            State  \
# 0    RH-19495       Rick Hansen     Consumer  New York City         New York
# 1    JR-16210     Justin Ritter    Corporate     Wollongong  New South Wales
# 2    CR-12730      Craig Reiter     Consumer       Brisbane       Queensland
# 3    KM-16375  Katherine Murray  Home Office         Berlin           Berlin
# 4     RH-9495       Rick Hansen     Consumer          Dakar            Dakar
#
#    ...        Product ID    Category Sub-Category  \
# 0  ...   TEC-AC-10003033  Technology  Accessories
# 1  ...   FUR-CH-10003950   Furniture       Chairs
# 2  ...   TEC-PH-10004664  Technology       Phones
# 3  ...   TEC-PH-10004583  Technology       Phones
# 4  ...  TEC-SHA-10000501  Technology      Copiers
#
#                                         Product Name     Sales Quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1          Novimex Executive Leather Armchair, Black  3709.395        9
# 2                  Nokia Smart Phone, with Caller ID  5175.171        9
# 3                     Motorola Smart Phone, Cordless  2892.510        5
# 4                     Sharp Wireless Fax, High-Speed  2832.960        8
#
#   Discount    Profit  Shipping Cost  Order Priority
# 0      0.0  762.1845         933.57        Critical
# 1      0.1 -288.7650         923.63        Critical
# 2      0.1  919.9710         915.49          Medium
# 3      0.1  -96.5400         910.16          Medium
# 4      0.0  311.5200         903.04        Critical
#
# [5 rows x 24 columns]

# %%
print(df.shape)
print(df.columns)
# Out:
# (51290, 24)
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
# countries_profit_region=df[["Country","Profit","Region"]]
# countries_profit.head()
# africa_profit=countries_profit_region[countries_profit_region["Region"]=="Africa"]
# africa_profit.head()

# %%
africaProfitData = df[df["Region"]=="Africa"]
africaProfitData.head()
# Out:
#     Row ID      Order ID Order Date            Ship Date     Ship Mode  \
# 4    47221  SG-2013-4320 2015-11-05  2015-11-06 00:00:00      Same Day
# 19   49463  TZ-2014-8190 2016-12-05  2016-12-07 00:00:00  Second Class
# 35   47905  CG-2011-8610 2013-09-14  2013-09-15 00:00:00   First Class
# 54   42336  MZ-2013-3690 2015-12-18  2015-12-18 00:00:00      Same Day
# 72   49085  CG-2013-6110 2015-03-29  2015-03-31 00:00:00  Second Class
#
#    Customer ID    Customer Name    Segment     City             State  ...  \
# 4      RH-9495      Rick Hansen   Consumer    Dakar             Dakar  ...
# 19     RH-9555  Ritsa Hightower   Consumer   Uvinza            Kigoma  ...
# 35       AH-30    Aaron Hawkins  Corporate   Kamina           Katanga  ...
# 54     DG-3300    Deirdre Greer  Corporate   Maputo  Cidade De Maputo  ...
# 72     BW-1065    Barry Weirich   Consumer  Kananga  Kasai-Occidental  ...
#
#           Product ID         Category Sub-Category  \
# 4   TEC-SHA-10000501       Technology      Copiers
# 19  OFF-KIT-10004058  Office Supplies   Appliances
# 35  TEC-APP-10000308       Technology       Phones
# 54  TEC-MOT-10002272       Technology       Phones
# 72  FUR-HAR-10002873        Furniture       Chairs
#
#                                          Product Name    Sales Quantity  \
# 4                      Sharp Wireless Fax, High-Speed  2832.96        8
# 19                            KitchenAid Stove, White  3409.74        6
# 35                       Apple Smart Phone, Full Size  3817.26        6
# 54               Motorola Smart Phone, with Caller ID  2582.16        4
# 72  Harbour Creations Executive Leather Armchair, ...  3808.80        8
#
#    Discount   Profit  Shipping Cost  Order Priority
# 4       0.0   311.52         903.04        Critical
# 19      0.0   818.28         763.38            High
# 35      0.0  1068.66         678.15            High
# 54      0.0   593.88         627.17            High
# 72      0.0  1523.52         588.13            High
#
# [5 rows x 24 columns]

# %%
# profit_grouped_country=africa_profit[["Country","Profit"]].groupby("Country").describe()
# profit_grouped_country.head()
profit_Country=africaProfitData[["Country", "Profit","Sales","Shipping Cost","Discount"]]
profit_grouped_country =profit_Country.groupby("Country").agg(["sum","mean"])
profit_grouped_country.head()
# Out:
#            Profit                Sales             Shipping Cost             \
#               sum       mean       sum        mean           sum       mean
# Country
# Algeria   9106.50  46.461735  36091.59  184.140765       3726.41  19.012296
# Angola    6494.97  53.237459  25554.00  209.459016       2418.40  19.822951
# Benin     1349.19  38.548286   6212.07  177.487714        653.32  18.666286
# Burundi    103.08  51.540000    267.72  133.860000         18.51   9.255000
# Cameroon  5664.75  51.497727  22349.37  203.176091       2713.03  24.663909
#
#          Discount
#               sum mean
# Country
# Algeria       0.0  0.0
# Angola        0.0  0.0
# Benin         0.0  0.0
# Burundi       0.0  0.0
# Cameroon      0.0  0.0

# %%
profit_grouped_country.sort_values([('Profit', 'sum')], ascending=True).head()
# Out:
#                       Profit                 Sales            Shipping Cost  \
#                          sum       mean        sum       mean           sum
# Country
# Nigeria           -80750.718 -89.227313  54350.352  60.055638       6183.11
# Zimbabwe           -5428.785 -67.859812   3765.105  47.063813        476.22
# Uganda             -2426.085 -65.569865   1621.935  43.836081        165.89
# Equatorial Guinea     44.460  14.820000    150.510  50.170000          9.38
# Eritrea               76.200  38.100000    187.740  93.870000          8.55
#
#                             Discount
#                        mean      sum mean
# Country
# Nigeria            6.832166    633.5  0.7
# Zimbabwe           5.952750     56.0  0.7
# Uganda             4.483514     25.9  0.7
# Equatorial Guinea  3.126667      0.0  0.0
# Eritrea            4.275000      0.0  0.0

# %%
profit_grouped_country.apply(lambda x: x.sort_values()).head()
# Out:
#            Profit                Sales             Shipping Cost             \
#               sum       mean       sum        mean           sum       mean
# Algeria   9106.50  46.461735  36091.59  184.140765       3726.41  19.012296
# Angola    6494.97  53.237459  25554.00  209.459016       2418.40  19.822951
# Benin     1349.19  38.548286   6212.07  177.487714        653.32  18.666286
# Burundi    103.08  51.540000    267.72  133.860000         18.51   9.255000
# Cameroon  5664.75  51.497727  22349.37  203.176091       2713.03  24.663909
#
#          Discount
#               sum mean
# Algeria       0.0  0.0
# Angola        0.0  0.0
# Benin         0.0  0.0
# Burundi       0.0  0.0
# Cameroon      0.0  0.0

# %%
# africaProfitData[["Country", "Profit","Sales","Shipping Cost","Discount"]].groupby("Country").agg({'Profit': ["count",'min', 'max', 'median', 'skew'],
#              'Sales': ['min', 'max', 'median', 'mean']}).sort_values("Profit")

# %%
display(sorted_african_profit[sorted_african_profit.Country == "Nigeria"]).head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-140-c694876c625d> in <module>
# ----> 1 display(sorted_african_profit[sorted_african_profit.Country == "Nigeria"]).head()
#
# E:\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Country'

# %%
sorted_african_profit.Country
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-47c78fcb2f07> in <module>
# ----> 1 sorted_african_profit.Country
#
# E:\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Country'

# %%
print("Nigeria total profit for 2014 :"+ str(sorted_african_profit["Profit"][0]))
# Out:
# Nigeria total profit for 2014 :-80750.71799999978

# %%
sorted_african_profit['Profit'][1:11].plot(kind='bar')

# Set the title and labels
plt.xlabel('Countries')
plt.ylabel('Profit')
plt.title('10 Countries with least Profit')

# show the plot
plt.show()
